# %%
# Job Postings Count (1.2.1)
job_count = 42
print ("Total Jobs: ", job_count)
# Out:
# Total Jobs:  42

# %%
#Store Job Information (1.2.2)
job_title = "Data Engineer"
company_name = "DataWorks" 
remote_status = True
print("Job Title :", job_title)
print("Comapny Name :", company_name)
print("Remote Status :", remote_status)
# Out:
# JOb Title : Data Engineer
# Comapny Name : DataWorks
# Remote Status : True

# %%
#Calculate Total Compensation (1.2.3) - Problem
base_salary = 120000 
bonus = 20000  
total_compensation = base_salary + bonus
print("Total Compensation", total_compensation)
# Out:
# Total Compensation 140000

# %%
#Calculate Monthly Salary (1.2.4) - Problem
annual_salary = 72000
Monthly_Salary = annual_salary/12
print(Monthly_Salary)
# Out:
# 6000.0

# %%
#Calculate Total Compensation with Bonus (1.2.5)
job_title = "Data Scientist"
company_name = "AI Solutions" 
salary = 110000
compensation = salary + salary * 10/100
print("Total Salary :", compensation)
print("Comapny Name :", company_name)
print("Remote Status :", job_title)
# Out:
# Total Salary : 121000.0
# Comapny Name : AI Solutions
# Remote Status : Data Scientist
